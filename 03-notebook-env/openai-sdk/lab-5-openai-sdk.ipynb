# %% [markdown]
# ## Lab 5
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model
# here instruction is system prompt
# open SDK is able to work with many models - groq / gemini / openai

agent = Agent(name="Jokester", instructions="You are a good joke teller", model="gpt-4o-mini")

# %%
agent
# Out:
# Agent(name='Jokester', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a good joke teller', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, prompt_cache_retention=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output
# Runner.run(agent, "Tell a joke about Autonomous AI Agents") will return a coroutine object

with trace(workflow_name="Telling a joke part 2",trace_id="trace_myworkflow") as span:
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its partner?
#
# Because it just couldn't compute their emotional data!

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

load_dotenv(override=True)

agent = Agent(
    name="Jokester",
    instructions="You are a joke teller",
    model="gpt-4o-mini",
)

# ✅ tracing via the agents framework (not the SDK)

with trace(workflow_name="Telling a joke part 2", trace_id="my-trace-001") as span:
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its partner?
#
# Because it just couldn’t find the right “algorithm” for love!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
